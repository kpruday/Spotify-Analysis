# %% [markdown]
# ## Introduction:
#
# In today's digital age, music streaming platforms have revolutionized the way we consume music, offering vast libraries of songs at our fingertips. Among these platforms, Spotify stands out as a global leader, providing users with personalized playlists, curated recommendations, and insights into their listening habits.
#
# In this Spotify Data Analysis project, we delve into a dataset containing information about tracks available on Spotify. Using Python and various data analysis techniques, we aim to uncover valuable insights into the characteristics of these tracks, trends over time, and factors influencing their popularity.
#
# ## Project Overview:
#
# We kick off our analysis by loading the dataset and performing an initial exploration to understand its structure and contents. We inspect for missing values, examine data types, and generate summary statistics to gain a comprehensive understanding of the data.
#
# Next, we identify the most popular tracks based on their popularity scores, allowing us to highlight the standout performers in the dataset. Additionally, we investigate correlations between different attributes of the tracks, such as tempo, energy, and danceability, shedding light on potential relationships between these features.
#
# Furthermore, we explore temporal trends by analyzing the distribution of songs across different years, providing insights into the evolution of music over time. We also examine the duration of songs across various genres, uncovering patterns and variations in song lengths.
#
# To visually represent our findings, we leverage popular Python libraries such as Matplotlib and Seaborn to create informative visualizations. Through these visualizations, we aim to communicate our insights effectively and engage our audience with compelling charts and graphs.
#
# We aim to provide a comprehensive analysis of Spotify's track data, offering valuable insights for music enthusiasts, industry professionals, and data enthusiasts alike. Join us on this exciting journey as we explore the fascinating world of music data analysis.

# %% [markdown]
# **Analysis:**
#
# 1. **Data Loading and Exploration:**
#    - Load the dataset containing information about Spotify tracks using Pandas.
#    - Explore the structure of the dataset, including the number of rows and columns, and display the first few rows to understand the data's format.
#    - Check for missing values and examine data types to ensure data integrity.
#
# 2. **Identifying Popular Tracks:**
#    - Determine the most popular tracks based on Spotify's popularity score.
#    - Sort the data in descending order of popularity and extract the top-performing tracks.
#    - Analyze attributes of these tracks to understand common characteristics associated with popularity.
#
# 3. **Exploring Correlations:**
#    - Identify correlations between different attributes of the tracks, such as tempo, energy, and danceability.
#    - Compute correlation coefficients and visualize correlations using heatmaps to identify significant relationships.
#    - Interpret the findings to understand how these attributes contribute to a track's popularity and listener engagement.
#
# 4. **Temporal Trends Analysis:**
#    - Analyze temporal trends in music production and consumption by examining the distribution of songs across different years.
#    - Plot the number of songs released each year to identify trends, spikes, or declines in music production over time.
#    - Explore any notable patterns or shifts in musical preferences and genres across different periods.
#
# 5. **Genre-specific Analysis:**
#    - Investigate the duration of songs across various genres to understand genre-specific conventions and listener preferences regarding song length.
#    - Use descriptive statistics and visualizations to compare song durations within and across different musical categories.
#    - Identify genres with the longest and shortest song durations and explore potential reasons for these variations.
#
# 6. **Creating Visualizations:**
#    - Utilize Matplotlib and Seaborn libraries to create informative visualizations, including bar plots, line charts, histograms, and heatmaps.
#    - Customize visualizations to effectively communicate insights and trends discovered during the analysis.
#    - Enhance the visual appeal by adding titles, labels, and annotations to clarify the key takeaways from each visualization.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('tracks.csv')
data.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %%
# null values: number of missing values
pd.isnull(data).sum()
# Out:
# id                   0
# name                71
# popularity           0
# duration_ms          0
# explicit             0
# artists              0
# id_artists           0
# release_date         0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# time_signature       0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   duration_ms       586672 non-null  int64
#  4   explicit          586672 non-null  int64
#  5   artists           586672 non-null  object
#  6   id_artists        586672 non-null  object
#  7   release_date      586672 non-null  object
#  8   danceability      586672 non-null  float64
#  9   energy            586672 non-null  float64
#  10  key               586672 non-null  int64
#  11  loudness          586672 non-null  float64
#  12  mode              586672 non-null  int64
#  13  speechiness       586672 non-null  float64
#  14  acousticness      586672 non-null  float64
#  15  instrumentalness  586672 non-null  float64
# ...

# %%
sorted_data = data.sort_values('popularity', ascending = True).head(10)
sorted_data
# Out:
#                             id  \
# 546130  181rTRhCcggZPwP2TUcVqm
# 546222  0yOCz3V5KMm8l1T8EFc60i
# 546221  0y48Hhwe52099UqYjegRCO
# 546220  0xCmgtf9ka07hkZg3D6PaV
# 546219  0tBXS3VuCPX7KWUFH2nros
# 546218  0qrKnQtYDVJhKFAXTHYVS9
# 546217  0nqsDxOeKSwEzp3AUQAAqS
# 546216  0kGEdsxVLYjCdfxM9tbezd
# 546215  0bc3PUZurUUXrY7yqoOxjq
# 546214  0Wwm0ruSjYMIiWG0nyAI1F
#
#                                                      name  popularity  \
# 546130       Newspaper Reports On Abner, 20 February 1935           0
# 546222                                             恋は水の上で           0
# 546221                                              私の誕生日           0
# 546220                                エル・チョクロ (EL CHOCLO)           0
# 546219                                           恋は不思議なもの           0
# 546218                         ゆうべはどうしたの (WHATSA MALLA U)           0
# 546217  Screen Director's Playhouse, Music For Million...           0
# ...

# %%
data.describe().transpose()
# Out:
#                      count           mean            std     min          25%  \
# popularity        586672.0      27.570053      18.370642     0.0      13.0000
# duration_ms       586672.0  230051.167286  126526.087418  3344.0  175093.0000
# explicit          586672.0       0.044086       0.205286     0.0       0.0000
# danceability      586672.0       0.563594       0.166103     0.0       0.4530
# energy            586672.0       0.542036       0.251923     0.0       0.3430
# key               586672.0       5.221603       3.519423     0.0       2.0000
# loudness          586672.0     -10.206067       5.089328   -60.0     -12.8910
# mode              586672.0       0.658797       0.474114     0.0       0.0000
# speechiness       586672.0       0.104864       0.179893     0.0       0.0340
# acousticness      586672.0       0.449863       0.348837     0.0       0.0969
# instrumentalness  586672.0       0.113451       0.266868     0.0       0.0000
# ...

# %%
most_popular = data.query('popularity>90', inplace = False).sort_values('popularity', ascending = False)
most_popular[:10]
# Out:
#                            id                                    name  \
# 93802  4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon)
# 93803  7lPN2DXiMsVn7XUKtOW1CS                         drivers license
# 93804  3Ofmpyhv5UAQ70mENzB277                  Astronaut In The Ocean
# 92810  5QO79kh1waicV47BqGRL3g                         Save Your Tears
# 92811  6tDDoYIxWvMLTdKpjFkc1B                               telepatía
# 92813  0VjIjW4GlUZAMYd2vXMi3b                         Blinding Lights
# 93805  7MAibcTli4IisCtbHKrGMh                     Leave The Door Open
# 92814  6f3Slt0GbA2bPZlz0aIFXN                            The Business
# 91866  60ynsPSSKe6O3sfwRnIBRf                                 Streets
# 92816  3FAJ6O0NOHQV8Mc5Ri6ENp                  Heartbreak Anniversary
#
#        popularity  duration_ms  explicit  \
# 93802         100       198082         1
# 93803          99       242014         1
# 93804          98       132780         0
# ...

# %%
data.set_index("release_date", inplace = True)
data.head()
# Out:
#                                   id                                 name  \
# release_date
# 1922-02-22    35iwgR4jXetI318WEWsa1Q                                Carve
# 1922-06-01    021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 1922-03-21    07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 1922-03-21    08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 1922          08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
#
#               popularity  duration_ms  explicit              artists  \
# release_date
# 1922-02-22             6       126903         0              ['Uli']
# 1922-06-01             0        98200         0  ['Fernando Pessoa']
# 1922-03-21             0       181640         0  ['Ignacio Corsini']
# 1922-03-21             0       176907         0  ['Ignacio Corsini']
# 1922                   0       163080         0      ['Dick Haymes']
#
# ...

# %%
data[['artists']].iloc[18]
# Out:
# artists    ['Victor Boucher']
# Name: 1922, dtype: object

# %%
data['duration']=data['duration_ms'].apply(lambda x: round(x/1000))
data.drop('duration_ms', inplace=True, axis=1)

# %%
data.duration.head()
# Out:
# release_date
# 1922-02-22    127
# 1922-06-01     98
# 1922-03-21    182
# 1922-03-21    177
# 1922          163
# Name: duration, dtype: int64

# %%
# Check for non-numeric values in each column
non_numeric_values = data.applymap(lambda x: not isinstance(x, (int, float)))
print(non_numeric_values.any())
# Out:
# /tmp/ipykernel_1126/2108701616.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   non_numeric_values = data.applymap(lambda x: not isinstance(x, (int, float)))
# id                   True
# name                 True
# popularity          False
# explicit            False
# artists              True
# id_artists           True
# danceability        False
# energy              False
# key                 False
# loudness            False
# mode                False
# speechiness         False
# acousticness        False
# instrumentalness    False
# liveness            False
# valence             False
# tempo               False
# time_signature      False
# duration            False
# dtype: bool

# %%
corr_df=data.drop(["key","mode","explicit","id","name","artists","id_artists"],axis=1).corr(method="pearson")
plt.figure(figsize=(14,6))
heatmap=sns.heatmap(corr_df,annot=True,fmt=".1g",vmin=-1,vmax=1,center=0,cmap="inferno",linewidth=1,linecolor="Black")
heatmap.set_title("Correlation HeatMap Between Variables")
heatmap.set_xticklabels(heatmap.get_xticklabels(), rotation=90)
# Out:
# [Text(0.5, 0, 'popularity'),
#  Text(1.5, 0, 'danceability'),
#  Text(2.5, 0, 'energy'),
#  Text(3.5, 0, 'loudness'),
#  Text(4.5, 0, 'speechiness'),
#  Text(5.5, 0, 'acousticness'),
#  Text(6.5, 0, 'instrumentalness'),
#  Text(7.5, 0, 'liveness'),
#  Text(8.5, 0, 'valence'),
#  Text(9.5, 0, 'tempo'),
#  Text(10.5, 0, 'time_signature'),
#  Text(11.5, 0, 'duration')]

# %%
sample_df=data.sample(int(0.004*len(data)))

# %%
print(len(sample_df))
# Out:
# 2346

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=sample_df, y="loudness", x="energy", color="c").set(title = "Loudness Vs Energy Correlation")
# Out:
# [Text(0.5, 1.0, 'Loudness Vs Energy Correlation')]

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=sample_df, y="popularity", x="acousticness", color="b").set(title = "Popularity Vs Accousticness Correlation")
# Out:
# [Text(0.5, 1.0, 'Popularity Vs Accousticness Correlation')]

# %%
data['dates'] = data.index.get_level_values('release_date')
data['dates'] = pd.to_datetime(data['dates'], errors='coerce', format='%Y-%m-%d')
years_mask = data['dates'].isnull()  
data.loc[years_mask, 'dates'] = pd.to_datetime(data.loc[years_mask, 'dates'], errors='coerce', format='%Y')
years = data['dates'].dt.year

# %%
sns.displot(years,discrete=True,aspect=2,height=5,kind="hist").set(title="Number of songs per year")

# %%
data1 = pd.read_csv('SpotifyFeatures.csv')
data1.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# ...

# %%
plt.title("Duration of the songs in Different Genres")
sns.color_palette("Set2", as_cmap = True)
sns.barplot(y='genre', x='duration_ms', data=data1)
plt.xlabel("Duration in milli seconds")
plt.ylabel("Genres")
# Out:
# Text(0, 0.5, 'Genres')

# %%
sns.set_style(style="darkgrid")
plt.figure(figsize=(10,5))
famous=data1.sort_values("popularity", ascending =False).head(10)
sns.barplot(y='genre',x='popularity',data=famous).set(title="Top 5 Genres by Popularity")
# Out:
# [Text(0.5, 1.0, 'Top 5 Genres by Popularity')]

# %% [markdown]
# ## Conclusion
#
# - The Top 5 Generes by Popularity are: Dance, Pop, Rap, Hip-Hop, Reggaeton.
# - The Genre with the lowest duration is Children's Music.
# - The Genre with the highest duration is World.
# - The number of songs increases as the time passes from 1920 to 2020.
# reture analyses.

# %% [markdown]
# ### Implications for Music Industry Professionals, Artists, and Listeners:
#
# - Targeting Popular Genres: Understanding the top genres by popularity can guide music industry professionals and artists in strategic decision-making. They can focus their efforts on creating and promoting music within these genres to maximize audience reach and engagement.
#
# - Genre-specific Strategies: Recognizing the variation in song durations across different genres allows industry professionals and artists to tailor their creative approaches accordingly. For example, artists in genres with shorter average durations may prioritize concise and impactful compositions, while those in genres with longer durations may explore more intricate and expansive musical arrangements.
#
# - Adapting to Temporal Trends: The observed increase in the number of songs over time highlights the dynamic nature of the music industry. Industry professionals and artists can leverage temporal trends to stay informed about evolving audience preferences and adapt their strategies accordingly. Additionally, understanding historical trends can inform forecasting and planning for future releases.

# %% [markdown]
# ### Recommendations for Further Exploration:
# - In-depth Genre Analysis: While the top genres by popularity have been identified, further exploration could involve a deeper analysis of sub-genres and niche categories within each genre. This granular understanding can provide valuable insights into specific audience preferences and emerging trends that may not be apparent at a broader genre level.
#
# - Temporal Analysis of Genre Popularity: Investigating how the popularity of genres has evolved over time can offer insights into cultural shifts, societal influences, and technological advancements impacting music consumption. By analyzing historical data, researchers can identify trends and patterns that inform predictions about future genre popularity.
#
# - User Behavior Analysis: Exploring user behavior data, such as listening habits, playlist creation, and engagement metrics, can provide a more comprehensive understanding of audience preferences and music consumption patterns on Spotify. This analysis can inform personalized recommendations, targeted marketing strategies, and user experience enhancements on the platform.
#
# - Cross-platform Analysis: Extending the analysis beyond Spotify to include other music streaming platforms or traditional media channels can provide a broader perspective on music consumption trends. Comparative analysis across platforms can reveal unique audience behaviors, platform-specific preferences, and opportunities for cross-platform promotion and distribute analyses.

# %% [markdown]
# ## References
#
# 1) Spotify Tracks Database: https://www.kaggle.com/datasets/zaheenhamidani/ultimate-spotify-tracks-db/code
#
# 2) Spotify Datasets: https://www.kaggle.com/datasets/lehaknarnauli/spotify-datasets
